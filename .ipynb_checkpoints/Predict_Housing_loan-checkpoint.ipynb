# %% [markdown]
# # Predict if customer will need a housing loan or not

# %%
import numpy as np
import pandas as pd


newDF = pd.read_csv('bank-full-dataset.csv')
newDF
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# ### Cleaning the dataset

# %%
#change prediction column name

newDF.rename(columns={'y':'ifCreatedAccount'},inplace=True)
newDF.rename(columns={'housing':'housingLoan'}, inplace =True)

newDF
# Out:
#        age           job   marital  education default  balance housingLoan  \
# 0       58    management   married   tertiary      no     2143         yes
# 1       44    technician    single  secondary      no       29         yes
# 2       33  entrepreneur   married  secondary      no        2         yes
# 3       47   blue-collar   married    unknown      no     1506         yes
# 4       33       unknown    single    unknown      no        1          no
# ...    ...           ...       ...        ...     ...      ...         ...
# 45206   51    technician   married   tertiary      no      825          no
# 45207   71       retired  divorced    primary      no     1729          no
# 45208   72       retired   married  secondary      no     5715          no
# 45209   57   blue-collar   married  secondary      no      668          no
# 45210   37  entrepreneur   married  secondary      no     2971          no
#
# ...

# %%
#drop columns with too many 'unknown' values
#drop contact and poutcome

newDF.drop(['contact', 'poutcome'], axis='columns', inplace=True)

##after doing filter based feature selection in Azure Machine Learning Studio, the highest 7 features were selected
#drop columns that aren't required

newDF.drop([ 'previous', 'duration', 'default', 'marital', 'loan', 'day', 'campaign'], axis='columns', inplace=True)
newDF
# Out:
#        age           job  education  balance housingLoan month  pdays  \
# 0       58    management   tertiary     2143         yes   may     -1
# 1       44    technician  secondary       29         yes   may     -1
# 2       33  entrepreneur  secondary        2         yes   may     -1
# 3       47   blue-collar    unknown     1506         yes   may     -1
# 4       33       unknown    unknown        1          no   may     -1
# ...    ...           ...        ...      ...         ...   ...    ...
# 45206   51    technician   tertiary      825          no   nov     -1
# 45207   71       retired    primary     1729          no   nov     -1
# 45208   72       retired  secondary     5715          no   nov    184
# 45209   57   blue-collar  secondary      668          no   nov     -1
# 45210   37  entrepreneur  secondary     2971          no   nov    188
#
#       ifCreatedAccount
# 0                   no
# 1                   no
# 2                   no
# 3                   no
# ...

# %%
newDF['education'].value_counts()
# Out:
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64

# %%
#change yes = 1 no = 0
#give values to each job and each month from 1 to 12

newDF['ifCreatedAccount'] = newDF['ifCreatedAccount'].map({'yes': 1, 'no': 0})
newDF['month'] = newDF['month'].map({'jan': 1, 'feb': 2,'mar':3,'apr': 4,'may': 5, 'jun': 6, 'jul': 7, 'aug': 8, 'sep': 9,'oct':10,'nov': 11,'dec': 12})
newDF['housingLoan'] = newDF['housingLoan'].map({'yes': 1, 'no': 0})
newDF['job'] = newDF['job'].map({'blue-collar': 1, 'management': 2,'technician':3,'admin.': 4,'services': 5, 'retired': 6, 'self-employed': 7, 'entrepreneur': 8, 'unemployed': 9,'housemaid':10,'student': 11,'unknown': 12})
newDF['education'] = newDF['education'].map({'primary': 1, 'secondary': 2,'tertiary':3,'unknown': 0})


newDF
# Out:
#        age  job  education  balance  housingLoan  month  pdays  \
# 0       58    2          3     2143            1      5     -1
# 1       44    3          2       29            1      5     -1
# 2       33    8          2        2            1      5     -1
# 3       47    1          0     1506            1      5     -1
# 4       33   12          0        1            0      5     -1
# ...    ...  ...        ...      ...          ...    ...    ...
# 45206   51    3          3      825            0     11     -1
# 45207   71    6          1     1729            0     11     -1
# 45208   72    6          2     5715            0     11    184
# 45209   57    1          2      668            0     11     -1
# 45210   37    8          2     2971            0     11    188
#
#        ifCreatedAccount
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 45206                 1
# ...

# %%
#rearrange data columns

newDF = newDF[['age','job', 'education', 'balance', 'month', 'pdays', 'ifCreatedAccount', 'housingLoan']]
newDF.head()
# Out:
#    age  job  education  balance  month  pdays  ifCreatedAccount  housingLoan
# 0   58    2          3     2143      5     -1                 0            1
# 1   44    3          2       29      5     -1                 0            1
# 2   33    8          2        2      5     -1                 0            1
# 3   47    1          0     1506      5     -1                 0            1
# 4   33   12          0        1      5     -1                 0            0

# %%
newDF['housingLoan'].value_counts()
# Out:
# 1    25130
# 0    20081
# Name: housingLoan, dtype: int64

# %%
# Plot of Count
import matplotlib.pyplot as plt

newDF['housingLoan'].value_counts().plot(kind='bar')
plt.ylabel('Count')
plt.xlabel('Has housing loan or not')
# Out:
# Text(0.5, 0, 'Has housing loan or not')

# %%
#final dataset after cleaning

newDF . to_csv("cleanedHL.csv", index=False)

# %%
df2 = pd.read_csv('cleanedHL.csv')
df2
# Out:
#        age  job  education  balance  month  pdays  ifCreatedAccount  \
# 0       58    2          3     2143      5     -1                 0
# 1       44    3          2       29      5     -1                 0
# 2       33    8          2        2      5     -1                 0
# 3       47    1          0     1506      5     -1                 0
# 4       33   12          0        1      5     -1                 0
# ...    ...  ...        ...      ...    ...    ...               ...
# 45206   51    3          3      825     11     -1                 1
# 45207   71    6          1     1729     11     -1                 1
# 45208   72    6          2     5715     11    184                 1
# 45209   57    1          2      668     11     -1                 0
# 45210   37    8          2     2971     11    188                 0
#
#        housingLoan
# 0                1
# 1                1
# 2                1
# 3                1
# 4                0
# ...            ...
# ...

# %% [markdown]
# ### Creating models

# %%
newmDF = df2.sample(n = 10000, random_state = 2)

# %%
### Independent and Dependent features



X=newmDF.iloc[:,:-1]
y=newmDF.iloc[:,-1]

# %%
X.head()
# Out:
#        age  job  education  balance  month  pdays  ifCreatedAccount
# 28127   30    2          3      370      1    246                 0
# 20256   56   10          0     1780      8     -1                 0
# 6285    40    2          3      290      5     -1                 0
# 198     43    2          3      400      5     -1                 0
# 2417    28    1          0       52      5     -1                 0

# %%
y.tail()
# Out:
# 6596     0
# 7347     1
# 13433    0
# 39288    1
# 23728    0
# Name: housingLoan, dtype: int64

# %%
# Train Test Split
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
# Implement Random Forest classifier
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
# Prediction
y_pred=rfc.predict(X_test)

# %%
# Check Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_test,y_pred)
score
# Out:
# 0.7334119728693601

# %%
# Create a Pickle file using serialization for Random Forest Classifier
import pickle
pickle_out = open("H-RandomForestC.pkl","wb")
pickle.dump(rfc, pickle_out)
pickle_out.close()

# %%
#Implement Gaussian Naive Bayes classifier

from sklearn.naive_bayes import GaussianNB

NBclassifier = GaussianNB()
NBclassifier.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
NBy_pred=NBclassifier.predict(X_test)

# %%
#checking accuracy
NBscore=accuracy_score(y_test,NBy_pred)
NBscore
# Out:
# 0.6401503981126512

# %%
#Implement Decision Tree classifier

from sklearn.tree import DecisionTreeClassifier

DTclassifier = DecisionTreeClassifier()
DTclassifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
DTy_pred=DTclassifier.predict(X_test)

# %%
#checking accuracy
DTscore=accuracy_score(y_test,DTy_pred)
DTscore
# Out:
# 0.678782070185786

# %%
DT_pickle_out = open("H-DTClassifier.pkl","wb")
pickle.dump(DTclassifier, DT_pickle_out)
DT_pickle_out.close()

# %%
# KNN
from sklearn.neighbors import KNeighborsClassifier

KNNclassifier = KNeighborsClassifier(n_neighbors=5)
KNNclassifier.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
KNNy_pred=KNNclassifier.predict(X_test)

# %%
#checking accuracy
KNNscore=accuracy_score(y_test,KNNy_pred)
KNNscore
# Out:
# 0.6301975818342672

# %%
KNN_pickle_out = open("H-KNNClassifier.pkl","wb")
pickle.dump(KNNclassifier, KNN_pickle_out)
KNN_pickle_out.close()

# %% [markdown]
# ### Analysing data by plotting graphs

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
DGraph = df2.sample(n = 200, random_state = 2)

fig,ax = plt.subplots(figsize=(12,4))
sns.scatterplot(DGraph['job'],DGraph['housingLoan'])
ax.set(xlim=(0, 20))
# Out:
# [(0.0, 20.0)]

# %%
sns.scatterplot(x=DGraph['education'], y=DGraph['job'], hue=DGraph['housingLoan'],palette=['green','red'],data=DGraph)

# %%
graphs=["job","education","month", "ifCreatedAccount"]

y1 = df2['housingLoan']
y1 = y1.values



for i in graphs:
    
    sns.countplot(x=i, hue=y1, data=df2)
    plt.show()

# %% [markdown]
# ### Conclusions
# + many with blue collar jobs have taken housing loans
# + many with a secondary education have taken housing loans compared to others
# + most who were contacted in the month of may have taken housing loans
# + most who have taken housing loans dont have a fixed deposit account
